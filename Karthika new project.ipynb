# %%
import pandas as pd

# %%
df = pd.read_csv('UDISE_2023-24_Table_2.1.csv')

# %%
df.head(6)
# Out:
#    Sl. No.               India/State/UT  Total Number of - Schools  \
# 0        1                        India                    1471891
# 1        2  Andaman and Nicobar Islands                        412
# 2        3               Andhra Pradesh                      61373
# 3        4            Arunachal Pradesh                       3490
# 4        5                        Assam                      56630
# 5        6                        Bihar                      94686
#
#    Total Number of - Enrolments  Total Number of - Teachers  \
# 0                     248045828                     9807600
# 1                         72119                        5750
# 2                       8741885                      338293
# 3                        323717                       24700
# 4                       6922533                      342199
# 5                      21348149                      657063
#
#    Percentage Share of Schools by Category - Primary  \
# ...

# %%
df.tail(5)
# Out:
#     Sl. No. India/State/UT  Total Number of - Schools  \
# 32       33      Telangana                      42901
# 33       34        Tripura                       4923
# 34       35  Uttar Pradesh                     255087
# 35       36    Uttarakhand                      22551
# 36       37    West Bengal                      93945
#
#     Total Number of - Enrolments  Total Number of - Teachers  \
# 32                       7293644                      341460
# 33                        689408                       37661
# 34                      41662794                     1538479
# 35                       2372400                      130741
# 36                      18015525                      576557
#
#     Percentage Share of Schools by Category - Primary  \
# 32                                               47.9
# 33                                               50.2
# 34                                               52.3
# ...

# %%
df.
# Out:
# (37, 17)

# %%
df.columns
# Out:
# Index(['Sl. No.', 'India/State/UT', 'Total Number of - Schools',
#        'Total Number of - Enrolments', 'Total Number of - Teachers',
#        'Percentage Share of Schools by Category - Primary',
#        'Percentage Share of Schools by Category - Upper Primary',
#        'Percentage Share of Schools by Category - Secondary',
#        'Percentage Share of Schools by Category - Higher Secondary',
#        'Percentage Share of Enrolments by level -  Primary ',
#        'Percentage Share of Enrolments by level -  Upper Primary ',
#        'Percentage Share of Enrolments by level - Secondary',
#        'Percentage Share of Enrolments by level - Higher Secondary',
#        'Percentage Share of Teachers by School Category - Primary',
#        'Percentage Share of Teachers by School Category - Upper Primary',
#        'Percentage Share of Teachers by School Category - Secondary',
#        'Percentage Share of Teachers by School Category - Higher Secondary'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 17 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Sl. No.                                                             37 non-null     int64
#  1   India/State/UT                                                      37 non-null     str
#  2   Total Number of - Schools                                           37 non-null     int64
#  3   Total Number of - Enrolments                                        37 non-null     int64
#  4   Total Number of - Teachers                                          37 non-null     int64
#  5   Percentage Share of Schools by Category - Primary                   37 non-null     float64
#  6   Percentage Share of Schools by Category - Upper Primary             37 non-null     float64
# ...

# %%
df.sort_values(by=['Percentage Share of Schools by Category - Primary', 'Percentage Share of Schools by Category - Primary'], ascending=False).head(5)
# Out:
#     Sl. No.    India/State/UT  Total Number of - Schools  \
# 36       37       West Bengal                      93945
# 4         5             Assam                      56630
# 23       24         Meghalaya                      14601
# 2         3    Andhra Pradesh                      61373
# 13       14  Himachal Pradesh                      17826
#
#     Total Number of - Enrolments  Total Number of - Teachers  \
# 36                      18015525                      576557
# 4                        6922533                      342199
# 23                       1052884                       55726
# 2                        8741885                      338293
# 13                       1426412                      101131
#
#     Percentage Share of Schools by Category - Primary  \
# 36                                               79.3
# 4                                                66.2
# 23                                               62.7
# ...

# %%
df.describe()
# Out:
#          Sl. No.  Total Number of - Schools  Total Number of - Enrolments  \
# count  37.000000               3.700000e+01                  3.700000e+01
# mean   19.000000               7.956168e+04                  1.340788e+07
# std    10.824355               2.407658e+05                  4.057760e+07
# min     1.000000               3.700000e+01                  1.259100e+04
# 25%    10.000000               3.490000e+03                  3.237170e+05
# 50%    19.000000               2.351700e+04                  5.599742e+06
# 75%    28.000000               6.137300e+04                  1.149671e+07
# max    37.000000               1.471891e+06                  2.480458e+08
#
#        Total Number of - Teachers  \
# count                3.700000e+01
# mean                 5.301405e+05
# std                  1.598759e+06
# min                  9.110000e+02
# 25%                  2.470000e+04
# 50%                  2.065910e+05
# 75%                  3.940530e+05
# ...

# %%
df["India/State/UT"]
# Out:
# 0                                        India
# 1                  Andaman and Nicobar Islands
# 2                               Andhra Pradesh
# 3                            Arunachal Pradesh
# 4                                        Assam
# 5                                        Bihar
# 6                                   Chandigarh
# 7                                 Chhattisgarh
# 8     Dadra and Nagar Haveli and Daman and Diu
# 9                                        Delhi
# 10                                         Goa
# 11                                     Gujarat
# 12                                     Haryana
# 13                            Himachal Pradesh
# 14                           Jammu and Kashmir
# 15                                   Jharkhand
# 16                                   Karnataka
# 17                                      Kerala
# 18                                      Ladakh
# 19                                 Lakshadweep
# ...

# %%
df[[
    "India/State/UT",
    "Total Number of - Teachers",
    "Percentage Share of Schools by Category - Secondary"
]]
# Out:
#                               India/State/UT  Total Number of - Teachers  \
# 0                                      India                     9807600
# 1                Andaman and Nicobar Islands                        5750
# 2                             Andhra Pradesh                      338293
# 3                          Arunachal Pradesh                       24700
# 4                                      Assam                      342199
# 5                                      Bihar                      657063
# 6                                 Chandigarh                       10237
# 7                               Chhattisgarh                      278798
# 8   Dadra and Nagar Haveli and Daman and Diu                        4995
# 9                                      Delhi                      160479
# 10                                       Goa                       14594
# 11                                   Gujarat                      394053
# ...

# %%
df.sort_values(
    by="Total Number of - Schools",
    ascending=False
)[["India/State/UT", "Percentage Share of Schools by Category - Upper Primary"]].head(10)
# Out:
#     India/State/UT  Percentage Share of Schools by Category - Upper Primary
# 0            India                                               29.4
# 34   Uttar Pradesh                                               34.0
# 20  Madhya Pradesh                                               35.7
# 21     Maharashtra                                               27.0
# 29       Rajasthan                                               32.0
# 5            Bihar                                               42.7
# 36     West Bengal                                                9.2
# 16       Karnataka                                               40.0
# 26          Odisha                                               33.8
# 2   Andhra Pradesh                                               13.5

# %%
df.sort_values(
    by="Total Number of - Teachers",
    ascending=False
)[["India/State/UT", "Total Number of - Enrolments"]].head(10)
# Out:
#     India/State/UT  Total Number of - Enrolments
# 0            India                     248045828
# 34   Uttar Pradesh                      41662794
# 29       Rajasthan                      16786065
# 21     Maharashtra                      21375970
# 5            Bihar                      21348149
# 20  Madhya Pradesh                      15361543
# 36     West Bengal                      18015525
# 31      Tamil Nadu                      12993050
# 16       Karnataka                      11926303
# 11         Gujarat                      11496709

# %%
# Write your code here

# %%
df.sort_values(
    by="Percentage Share of Schools by Category - Primary",
    ascending=False
)[["India/State/UT", "Percentage Share of Enrolments by level - Higher Secondary"]].head(10)
# Out:
#       India/State/UT  \
# 36       West Bengal
# 4              Assam
# 23         Meghalaya
# 2     Andhra Pradesh
# 13  Himachal Pradesh
# 10               Goa
# 31        Tamil Nadu
# 7       Chhattisgarh
# 35       Uttarakhand
# 30            Sikkim
#
#     Percentage Share of Enrolments by level - Higher Secondary
# 36                                               11.5
# 4                                                 7.2
# 23                                                5.1
# 2                                                11.6
# 13                                               13.1
# 10                                               12.8
# 31                                               13.8
# 7                                                 9.7
# 35                                               13.1
# 30                                               13.0

# %%
df[df["India/State/UT"] == "Kerala"]
# Out:
#     Sl. No. India/State/UT  Total Number of - Schools  \
# 17       18         Kerala                      15864
#
#     Total Number of - Enrolments  Total Number of - Teachers  \
# 17                       6281704                      291096
#
#     Percentage Share of Schools by Category - Primary  \
# 17                                               40.4
#
#     Percentage Share of Schools by Category - Upper Primary  \
# 17                                               28.1
#
#     Percentage Share of Schools by Category - Secondary  \
# 17                                               12.5
#
#     Percentage Share of Schools by Category - Higher Secondary  \
# 17                                               19.0
#
#     Percentage Share of Enrolments by level -  Primary   \
# 17                                               46.3
#
#     Percentage Share of Enrolments by level -  Upper Primary   \
# 17                                               23.7
#
# ...

# %%
df[df["Percentage Share of Teachers by School Category - Secondary"] < 70][[
    "India/State/UT",
    "Percentage Share of Schools by Category - Secondary"
]]
# Out:
#                               India/State/UT  \
# 0                                      India
# 1                Andaman and Nicobar Islands
# 2                             Andhra Pradesh
# 3                          Arunachal Pradesh
# 4                                      Assam
# 5                                      Bihar
# 6                                 Chandigarh
# 7                               Chhattisgarh
# 8   Dadra and Nagar Haveli and Daman and Diu
# 9                                      Delhi
# 10                                       Goa
# 11                                   Gujarat
# 12                                   Haryana
# 13                          Himachal Pradesh
# 14                         Jammu and Kashmir
# 15                                 Jharkhand
# 16                                 Karnataka
# 17                                    Kerala
# 18                                    Ladakh
# 19                               Lakshadweep
# ...

# %%
df["Percentage Share of Schools by Category - Primary"].min()
# Out:
# np.float64(6.1)
